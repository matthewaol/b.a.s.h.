# %% [markdown]
# # [Python Reference Link](http://www.data8.org/sp20/python-reference.html)
# *Run the cell below so that we can set our modules up*

# %%
import numpy as np
from datascience import *
from IPython.display import YouTubeVideo

# These lines do some fancy plotting magic.
import matplotlib
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('fivethirtyeight')
import warnings
warnings.simplefilter('ignore', FutureWarning)
import pandas as pd

# %%
#table
df = pd.read_csv('cleaned_incidents.csv')
df
# Out:
#         Unnamed: 0.1  Unnamed: 0  Incident ID Report Type Code
# 0                  1           1      1253795               II  \
# 1                  2           6      1253816               II
# 2                  3           7      1254195               II
# 3                  4           8      1254206               IS
# 4                  5           9      1254318               II
# ...              ...         ...          ...              ...
# 764104        788109      788113      1256853               II
# 764105        788110      788114      1256652               II
# 764106        788111      788115      1256642               II
# 764107        788112      788116      1256873               II
# 764108        788113      788117      1256767               VI
#
#        Report Type Description    Incident Category
# 0             Coplogic Initial        Larceny Theft  \
# 1             Coplogic Initial        Larceny Theft
# ...

# %%
#isolate neighborhoods that crime happened in

neighborhoods_list = df[['Report Type Code','Police District','Incident Category','Incident Subcategory','Incident Description','Police District']]
neighborhoods_list.head(100)
# Out:
#    Report Type Code Police District Incident Category    Incident Subcategory
# 0                II         Mission     Larceny Theft   Larceny Theft - Other  \
# 1                II         Central     Larceny Theft  Larceny - From Vehicle
# 2                II         Central     Larceny Theft  Larceny - From Vehicle
# 3                IS         Central     Larceny Theft  Larceny - From Vehicle
# 4                II            Park           Assault          Simple Assault
# ..              ...             ...               ...                     ...
# 95               II        Southern      Non-Criminal            Non-Criminal
# 96               II         Bayview      Non-Criminal                   Other
# 97               II        Southern     Lost Property           Lost Property
# 98               II        Richmond     Lost Property           Lost Property
# 99               II        Southern     Larceny Theft  Larceny - From Vehicle
#
# ...
